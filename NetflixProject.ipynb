# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\netflix_analysis\netflix_titles.csv", encoding = "latin1")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#removing extra columns
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Nan values
#Checking which columns have Nan values and what percentage of the rows of that column are empty or Nan
#we can use the isnull and take a sum of the no. of values that are null
df.isnull().sum() * 100 / len(df)
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.901237
# cast             9.365422
# country          9.433534
# date_added       0.113520
# release_year     0.000000
# rating           0.045408
# duration         0.034056
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df['director'].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Peter Hewitt',
#        'Mozez Singh', 'Yeon Sang-ho'], dtype=object)

# %%
#checking how many Nans are in the column
df['director'].isna().sum()
# Out:
# 2634

# %%
#filling with placeholder
df['director'] = df['director'].fillna('Unknown')

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                          director  \
# 0                 Kirsten Johnson
# 1                         Unknown
# 2                 Julien Leclercq
# 3                         Unknown
# 4                         Unknown
# 5                   Mike Flanagan
# 6  Robert Cullen, Jos̩ Luis Ucha
# 7                    Haile Gerima
# 8                 Andy Devonshire
# ...

# %%
#filling with placeholder
df['country'] = df['country'].fillna('Unknown')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#filling with placeholder
df['cast'] = df['cast'].fillna('Unknown')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#number of tv shows and movies
df['type'].value_counts()
# Out:
# type
# Movie      6132
# TV Show    2677
# Name: count, dtype: int64

# %%
#top countries producing netflix content
df['country'].value_counts().head(10)
# Out:
# country
# United States     2819
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        200
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
#how many titles were added to netflix each year

# %%
#converts data_added column into date time format
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
#removing the extra spaces from date_added column so that pd.to_datetime works
# df['date_added'] = pd.to_datetime(df['date_added'].str.strip(), errors='coerce')
print(df['date_added'])
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# 8807   2024-04-05
# 8808   2024-04-05
# Name: date_added, Length: 8809, dtype: datetime64[ns]

# %%
#extracts the year part from the date added column and stores it in year_added column
df['year_added'] = df['date_added'].dt.year
print(df['year_added'])
# Out:
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# 8807    2024.0
# 8808    2024.0
# Name: year_added, Length: 8809, dtype: float64

# %%
#counts how many times each year appears in the year_added column
df['year_added'].value_counts().sort_index()
# Out:
# year_added
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      11
# 2014.0      24
# 2015.0      82
# 2016.0     429
# 2017.0    1188
# 2018.0    1649
# 2019.0    2016
# 2020.0    1879
# 2021.0    1498
# 2024.0       2
# Name: count, dtype: int64

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#most popular genres 
# df['listed_in'].value_counts().head(10)

#seperating every genre
split_genres = df['listed_in'].str.split(',')

# Expanding the list into individual genres
exploded_list = split_genres.explode()
# print(explode_list)

# Counting the popular genres individually
exploded_list.value_counts().head(10)
# Out:
# listed_in
#  International Movies     2624
# Dramas                    1600
# Comedies                  1210
# Action & Adventure         859
# Documentaries              829
#  Dramas                    827
# International TV Shows     774
#  Independent Movies        736
#  TV Dramas                 696
#  Romantic Movies           613
# Name: count, dtype: int64

# %%
df['listed_in'].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
#Top directors and actors
top_directors = df['director'].value_counts().head(10)
print(top_directors)

top_cast = df['cast'].str.split(',').explode().value_counts().head(10)
print('\n', top_cast)
# Out:
# director
# Rajiv Chilaka              19
# Ra̼l Campos, Jan Suter    18
# Marcus Raboy               16
# Suhas Kadav                16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Youssef Chahine            12
# Martin Scorsese            12
# Jay Chapman                12
# Steven Spielberg           11
# Name: count, dtype: int64
#
#  cast
#  Anupam Kher         39
#  Rupa Bhimani        31
#  Takahiro Sakurai    30
#  Julie Tejwani       28
#  Om Puri             27
# Shah Rukh Khan       26
#  Rajesh Kava         26
#  Paresh Rawal        25
#  Andrea Libman       25
#  Yuki Kaji           25
# Name: count, dtype: int64

# %%
#most common maturity ratings
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3208
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# A              1
# Name: count, dtype: int64
